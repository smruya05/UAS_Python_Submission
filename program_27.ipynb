# %% [markdown]
# <a href="https://colab.research.google.com/github/smruya05/UAS_Python_Submission/blob/main/program_27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Reading content from a file
try:
    with open("notes.txt", "r") as file:
        content = file.read()
        print("--- Content of notes.txt ---")
        print(content)
except FileNotFoundError:
    print("Error: 'notes.txt' not found. Please run Program 26 first.")
