# %% [markdown]
# <a href="https://colab.research.google.com/github/smruya05/UAS_Python_Submission/blob/main/program_30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
# Listing current directory files
path = "."
files = os.listdir(path)

print(f"Files in current directory '{os.getcwd()}':")
for f in files:
    print(f"- {f}")
