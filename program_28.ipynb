# %% [markdown]
# <a href="https://colab.research.google.com/github/smruya05/UAS_Python_Submission/blob/main/program_28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Adding content without overwriting
with open("notes.txt", "a") as file:
    file.write("\nLine 3: This line was appended.")

print("New line added to 'notes.txt'.")
