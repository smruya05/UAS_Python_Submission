# %% [markdown]
# <a href="https://colab.research.google.com/github/smruya05/UAS_Python_Submission/blob/main/program_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
# Simulating a dice roll
print("Rolling the dice...")
roll = random.randint(1, 6)

print(f"You rolled a: {roll}")
if roll == 6:
    print("Lucky! You got a six.")
