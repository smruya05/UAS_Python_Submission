# %% [markdown]
# <a href="https://colab.research.google.com/github/smruya05/UAS_Python_Submission/blob/main/program_29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Counting total words in a file
try:
    with open("notes.txt", "r") as file:
        data = file.read()
        words = data.split()
        print(f"The file contains {len(words)} words.")
except FileNotFoundError:
    print("File not found.")
