# %% [markdown]
# <a href="https://colab.research.google.com/github/smruya05/UAS_Python_Submission/blob/main/program_17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Working with Tuples (Immutable sequences)
coordinates = (40.7128, 74.0060)
print(f"Latitude: {coordinates[0]}")
print(f"Longitude: {coordinates[1]}")

try:
    coordinates[0] = 50.0  # This will trigger an error
except TypeError as e:
    print(f"Caught expected error: {e}")
