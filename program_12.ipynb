# %% [markdown]
# <a href="https://colab.research.google.com/github/smruya05/UAS_Python_Submission/blob/main/program_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Generating a multiplication table using range()
num = int(input("Show multiplication table of: "))

print(f"--- Table of {num} ---")
for i in range(1, 11):
    print(f"{num} x {i} = {num * i}")
