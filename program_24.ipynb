# %% [markdown]
# <a href="https://colab.research.google.com/github/smruya05/UAS_Python_Submission/blob/main/program_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Creating a list of even numbers using comprehension
limit = 20
evens = [x for x in range(limit) if x % 2 == 0]

print(f"Even numbers up to {limit}: {evens}")
print("Concept: List comprehension provides a concise way to create lists.")
