# %% [markdown]
# <a href="https://colab.research.google.com/github/smruya05/UAS_Python_Submission/blob/main/program_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program to demonstrate variable assignment and type casting
user_name = input("Please enter your full name: ")
birth_year = int(input("Enter your birth year: "))
current_year = 2026
calculated_age = current_year - birth_year

print("\n--- User Profile Summary ---")
print(f"Name recorded: {user_name}")
print(f"Age based on input: {calculated_age} years")
print(f"Data type of the name variable: {type(user_name)}")
print(f"Data type of the age variable: {type(calculated_age)}")
