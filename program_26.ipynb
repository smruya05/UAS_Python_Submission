# %% [markdown]
# <a href="https://colab.research.google.com/github/smruya05/UAS_Python_Submission/blob/main/program_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Creating and writing to a text file
file_name = "notes.txt"
with open(file_name, "w") as file:
    file.write("Line 1: Learning File I/O in Python.\n")
    file.write("Line 2: This file was created automatically.")

print(f"File '{file_name}' has been written successfully.")
